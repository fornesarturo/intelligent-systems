# %% [markdown]
# # Question 4
# ## Arturo Fornés Arvayo A01227071

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Models
from sklearn.svm import SVC

import csv
import pandas as pd

# %%
expected_prediction = [0, 1, 1, 0, 1]
expected_prediction
# Out:
# [0, 1, 1, 0, 1]

# %%
df_train = pd.read_csv("svm_linear.csv", header=None, names=["x", "y", "class"])
df_test = pd.read_csv("svm_linear_Test.csv", header=None, names=["x", "y", "class"])

# %%
df_train
# Out:
#            x         y  class
# 0  -0.177497  0.930496      1
# 1   1.977424  1.766155      0
# 2   1.800024  1.700343      0
# 3  -0.770837  2.359163      1
# 4  -0.308009  1.594063      1
# 5   0.614721  2.434898      1
# 6   1.090943  2.216634      0
# 7  -0.834890  2.358689      1
# 8   2.479465  1.334190      0
# 9   1.199266  1.826814      1
# 10  2.185062  0.822688      0
# 11  1.684232  1.041131      0
# 12  1.146211  2.070485      0
# 13  1.355969  0.568025      0
# 14  1.385207  1.826072      0
# 15  1.867292  1.186927      0
# 16  0.312274  2.246054      1
# 17 -0.081835  1.700655      1
# 18  0.904845  2.606830      1
# 19 -0.435861  2.015141      1
# 20  0.814412  2.135468      1
# 21  3.108743  2.267865      0
# 22 -0.255742  1.712811      1
# 23  1.886630  2.720895      0
# 24  2.295035  3.892678      0
# 25 -0.114156  0.855934      1
# 26  1.697035  3.477178      0
# 27  1.838558  0.926672      0
# 28  1.602988  1.301844      0
# 29  1.138032  2.829550      1
# ...

# %%
df_test_dropped = df_test.drop("class", axis=1)

# %%
df_test_dropped
# Out:
#           x         y
# 0  2.632382  1.271305
# 1 -0.040256  1.782708
# 2 -0.787453  1.400357
# 3  2.702441  1.587444
# 4  1.290969  2.751937

# %%
df_train.plot.scatter("x", "y", c="class", colormap='viridis')

# %%
classifier = SVC(kernel='sigmoid', C=1, gamma=1)

# %%
y = df_train["class"]
X = df_train.drop("class", axis=1)

# %%
X
# Out:
#            x         y
# 0  -0.177497  0.930496
# 1   1.977424  1.766155
# 2   1.800024  1.700343
# 3  -0.770837  2.359163
# 4  -0.308009  1.594063
# 5   0.614721  2.434898
# 6   1.090943  2.216634
# 7  -0.834890  2.358689
# 8   2.479465  1.334190
# 9   1.199266  1.826814
# 10  2.185062  0.822688
# 11  1.684232  1.041131
# 12  1.146211  2.070485
# 13  1.355969  0.568025
# 14  1.385207  1.826072
# 15  1.867292  1.186927
# 16  0.312274  2.246054
# 17 -0.081835  1.700655
# 18  0.904845  2.606830
# 19 -0.435861  2.015141
# 20  0.814412  2.135468
# 21  3.108743  2.267865
# 22 -0.255742  1.712811
# 23  1.886630  2.720895
# 24  2.295035  3.892678
# 25 -0.114156  0.855934
# 26  1.697035  3.477178
# 27  1.838558  0.926672
# 28  1.602988  1.301844
# 29  1.138032  2.829550
# ..       ...       ...
# 65 -1.660065  1.463135
# 66  1.243900  1.460046
# 67  1.879223  1.722623
# 68  2.908508  2.941591
# 69 -0.481226  1.791438
# 70  2.437430  1.345353
# 71  2.565799  0.993344
# 72  2.448992  2.490727
# ...

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     1
# 5     1
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    0
# 15    0
# 16    1
# 17    1
# 18    1
# 19    1
# 20    1
# 21    0
# 22    1
# 23    0
# 24    0
# 25    1
# 26    0
# 27    0
# 28    0
# 29    1
#      ..
# 65    1
# 66    0
# 67    0
# 68    0
# 69    1
# 70    0
# 71    0
# 72    0
# 73    1
# 74    1
# 75    1
# 76    0
# 77    1
# 78    1
# 79    1
# 80    0
# 81    0
# 82    0
# 83    1
# 84    1
# 85    1
# 86    0
# 87    1
# 88    1
# 89    1
# 90    0
# 91    1
# 92    0
# 93    0
# 94    1
# Name: class, Length: 95, dtype: int64

# %%
classifier.fit(X,y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=1, kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
predicted = classifier.predict(df_test_dropped)

# %%
print("Prediction should be:", expected_prediction)
print("Classifier predicted:", predicted)
print("Is correct?", expected_prediction == predicted)
# Out:
# Prediction should be: [0, 1, 1, 0, 1]
# Classifier predicted: [0 1 1 0 1]
# Is correct? [ True  True  True  True  True]
